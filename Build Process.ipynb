# %%
import nbformat as nbf
import glob
import shutil
import nb2html

retrieve_name_from_cell = lambda cell_source: cell_source.replace('#','').strip()

def retrieve_name_from_fname(fname):
    nb = nbf.read(open(fname),nbf.current_nbformat)
    for cell in nb['cells']:
        if cell['cell_type'] == 'markdown':
            return  retrieve_name_from_cell(cell['source'])
    return 'ERROR'

def get_manual_configuration():
    import yaml
    return yaml.load(open('notebooks/config.yml'))

def get_configuration():
    configuration = []
    for chapter_folder in sorted(glob.glob("notebooks/Chapter_*")):
        all_section_fnames = sorted(glob.glob("%s/*.ipynb"%chapter_folder))
        all_section_info = [
                dict(
                    file_name=fname.rpartition('/')[2],
                    section_name=retrieve_name_from_fname(fname)
                )
            for fname in all_section_fnames]

        chapter_name = all_section_info[0]['section_name']
        configuration.append(dict(
            chapter_name=chapter_name,
            folder_name=chapter_folder[10:],
            sections=all_section_info,
                        ))
    return configuration

# %%
#
#
# A function which makes the markdown file for a section
#
#

outline = """{}
------

{{% include "../notebooks-html/{}" %}}
"""

def make_md_file(title,ipynb_name,cold=False):
    filled_outline = outline.format(title,ipynb_name.replace('ipynb','html'))
    if cold:
        print(filled_outline)
        return
    with open('notebooks-md/%s'%(ipynb_name.replace('ipynb','md')),'w') as f:
        f.write(filled_outline)




#
#
# In this section
#  - python notebooks (.ipynb) are moved to "notebooks-flat"
#  - markdown files (.md) are generated for each section in "notebooks-md"
#
#

def copy_into_flat_directory(configuration,cold=False):
    shutil.copy2('notebooks/To_the_Student.ipynb','notebooks-flat/To_the_Student.ipynb')
    make_md_file('To The Student','To_the_Student.ipynb')


    for n,chapter in zip(range(1,len(configuration)+1),configuration):
        for section in chapter['sections']:
            src = ('notebooks/%s/%s'%(chapter['folder_name'],section['file_name']))
            dest = ('notebooks-flat/%d_%s'%(n,section['file_name']))

            ipynb_file = '%d_%s'%(n,section['file_name'])
            make_md_file(section['section_name'],ipynb_file,cold=cold)
            if cold:
                print("Copying from %s to %s"%(src,dest))
            else:
                shutil.copy2(src,dest)

# %%
#
#
# In this section
#  - The summary file (SUMMARY.md) is generated
#
#
def generate_summary(configuration,cold=False):
    SUMMARY_head = """
# Summary

* [To the Student](notebooks-md/To_the_Student.md)

    """

    chapter_summaries = [SUMMARY_head]

    for n,chapter in zip(range(1,len(configuration)+1),configuration):
        chapter_intro_md = chapter['sections'][0]['file_name'].replace('ipynb','md')
        entries = ['* [Chapter %d: %s](notebooks-md/%d_%s)'%(n,chapter['chapter_name'],n,chapter_intro_md)]
        for i,section in list(enumerate(chapter['sections']))[1:]:
            section_md = section['file_name'].replace ('ipynb','md')
            section_entry = ('\t* [%d.%d %s](notebooks-md/%d_%s)'%(n,i,section['section_name'],n,section_md))
            entries.append(section_entry)
        chapter_summaries.append('\n'.join(entries)+'\n')

    SUMMARY_md ="\n".join(chapter_summaries)
    if cold:
        print(SUMMARY_md)
    else:
        with open("SUMMARY.md","w") as f:
            f.write(SUMMARY_md)

# %%
#
#
# In this section
#  - basic html files are generated from "notebooks-flat", and placed in "notebooks-html"
#
#


configuration = get_configuration()
copy_into_flat_directory(configuration,cold=False)
generate_summary(configuration)
notebook_paths = glob.glob('notebooks-flat/*.ipynb')
nb2html.convert_notebooks_to_html_partial(notebook_paths)
generate_summary(configuration,cold=True)
# Out:
# filepath  filename 1_00_Fundamentals.ipynb basename 1_00_Fundamentals 1_00_Fundamentals.html
# ['1_00_Fundamentals.ipynb']
# http://prob140.berkeley.edu/user-redirect/interact?repo=prob140&path=textbook/1_00_Fundamentals.ipynb
# ./notebooks-html/1_00_Fundamentals.html written.
# filepath  filename 1_02_Equally_Likely_Outcomes.ipynb basename 1_02_Equally_Likely_Outcomes 1_02_Equally_Likely_Outcomes.html
# ['1_02_Equally_Likely_Outcomes.ipynb']
# http://prob140.berkeley.edu/user-redirect/interact?repo=prob140&path=textbook/1_02_Equally_Likely_Outcomes.ipynb
# ./notebooks-html/1_02_Equally_Likely_Outcomes.html written.
# filepath  filename 2_03_Multiplication.ipynb basename 2_03_Multiplication 2_03_Multiplication.html
# ['2_03_Multiplication.ipynb']
# http://prob140.berkeley.edu/user-redirect/interact?repo=prob140&path=textbook/2_03_Multiplication.ipynb
# ./notebooks-html/2_03_Multiplication.html written.
# filepath  filename 1_04_Birthday_Problem.ipynb basename 1_04_Birthday_Problem 1_04_Birthday_Problem.html
# ['1_04_Birthday_Problem.ipynb']
# http://prob140.berkeley.edu/user-redirect/interact?repo=prob140&path=textbook/1_04_Birthday_Problem.ipynb
# ./notebooks-html/1_04_Birthday_Problem.html written.
# filepath  filename 2_04_More_Examples.ipynb basename 2_04_More_Examples 2_04_More_Examples.html
# ['2_04_More_Examples.ipynb']
# http://prob140.berkeley.edu/user-redirect/interact?repo=prob140&path=textbook/2_04_More_Examples.ipynb
# ./notebooks-html/2_04_More_Examples.html written.
# filepath  filename 2_00_Calculating_Chances.ipynb basename 2_00_Calculating_Chances 2_00_Calculating_Chances.html
# ['2_00_Calculating_Chances.ipynb']
# http://prob140.berkeley.edu/user-redirect/interact?repo=prob140&path=textbook/2_00_Calculating_Chances.ipynb
# ./notebooks-html/2_00_Calculating_Chances.html written.
# filepath  filename 2_02_Examples.ipynb basename 2_02_Examples 2_02_Examples.html
# ['2_02_Examples.ipynb']
# http://prob140.berkeley.edu/user-redirect/interact?repo=prob140&path=textbook/2_02_Examples.ipynb
# ./notebooks-html/2_02_Examples.html written.
# filepath  filename 2_01_Addition.ipynb basename 2_01_Addition 2_01_Addition.html
# ['2_01_Addition.ipynb']
# http://prob140.berkeley.edu/user-redirect/interact?repo=prob140&path=textbook/2_01_Addition.ipynb
# ./notebooks-html/2_01_Addition.html written.
# filepath  filename 1_05_An_Exponential_Approximation.ipynb basename 1_05_An_Exponential_Approximation 1_05_An_Exponential_Approximation.html
# ['1_05_An_Exponential_Approximation.ipynb']
# http://prob140.berkeley.edu/user-redirect/interact?repo=prob140&path=textbook/1_05_An_Exponential_Approximation.ipynb
# ./notebooks-html/1_05_An_Exponential_Approximation.html written.
# filepath  filename 1_03_Collisions_in_Hashing.ipynb basename 1_03_Collisions_in_Hashing 1_03_Collisions_in_Hashing.html
# ['1_03_Collisions_in_Hashing.ipynb']
# http://prob140.berkeley.edu/user-redirect/interact?repo=prob140&path=textbook/1_03_Collisions_in_Hashing.ipynb
# ./notebooks-html/1_03_Collisions_in_Hashing.html written.
# filepath  filename 1_01_Outcome_Space_and_Events.ipynb basename 1_01_Outcome_Space_and_Events 1_01_Outcome_Space_and_Events.html
# ['1_01_Outcome_Space_and_Events.ipynb']
# http://prob140.berkeley.edu/user-redirect/interact?repo=prob140&path=textbook/1_01_Outcome_Space_and_Events.ipynb
# ./notebooks-html/1_01_Outcome_Space_and_Events.html written.
# filepath  filename 2_05_Updating_Probabilities.ipynb basename 2_05_Updating_Probabilities 2_05_Updating_Probabilities.html
# ['2_05_Updating_Probabilities.ipynb']
# http://prob140.berkeley.edu/user-redirect/interact?repo=prob140&path=textbook/2_05_Updating_Probabilities.ipynb
# ./notebooks-html/2_05_Updating_Probabilities.html written.
# filepath  filename To_the_Student.ipynb basename To_the_Student To_the_Student.html
# ['To_the_Student.ipynb']
# http://prob140.berkeley.edu/user-redirect/interact?repo=prob140&path=textbook/To_the_Student.ipynb
# ./notebooks-html/To_the_Student.html written.
#
# # Summary
#
# * [To the Student](notebooks-md/To_the_Student.md)
#
#
# * [Chapter 1: Fundamentals](notebooks-md/1_00_Fundamentals.md)
# 	* [1.1 Outcome Space and Events](notebooks-md/1_01_Outcome_Space_and_Events.md)
# 	* [1.2 Equally Likely Outcomes](notebooks-md/1_02_Equally_Likely_Outcomes.md)
# 	* [1.3 Collisions in Hashing](notebooks-md/1_03_Collisions_in_Hashing.md)
# 	* [1.4 The Birthday Problem](notebooks-md/1_04_Birthday_Problem.md)
# 	* [1.5 An Exponential Approximation](notebooks-md/1_05_An_Exponential_Approximation.md)
#
# * [Chapter 2: Calculating Chances](notebooks-md/2_00_Calculating_Chances.md)
# 	* [2.1 Addition](notebooks-md/2_01_Addition.md)
# 	* [2.2 Examples](notebooks-md/2_02_Examples.md)
# 	* [2.3 Multiplication](notebooks-md/2_03_Multiplication.md)
# 	* [2.4 More Examples](notebooks-md/2_04_More_Examples.md)
# 	* [2.5 Updating Probabilities](notebooks-md/2_05_Updating_Probabilities.md)
